# %% [markdown]
# # Correlation between Genomic Feature Position and DNA Sequence Information
# Does the information contained at a position in a DNA sequence correlate to the position of known genomic features?
#
#
# ## Definitions
# This is extremely ambigouous, we need some definitions.
#
# ### Binary Derivative
# For a binary string *s* of length n,
#
# $$S = s_0, s_1, ... s_{n-1}$$
#
# The binary derivative of S, *dS*, is another binary string given by the XOR value of all adjacent positions in the string *S*.
#
# This means
# $$|dS| + 1 = |S|$$
#
# And *dS* is defined as
# $$
# dS_i = \{ XOR(S_i, S_{i+1}) : i \in [0, n-1) \}
# $$
#
# ### DNA Sequence
# A finite string of {A, C, G, T} characters.
#
# ### GC Content
# The proportion of G|C characters in the DNA sequence string. Biologically, it reflects nucletide binding between the DNA double-helix strands https://en.wikipedia.org/wiki/GC-content.
#
#
# ### Binary Entropy
# TODO, defined for a binary sequence.
#
# ### DNA Information
# Loosly based on complexity. Defined by the length _L_ (bits) of a minimum-length program _P_ in the set of all programs that yield _S_, the binary sequence representation of the DNA sequence.
#
# The larger _L_ the larger the information.
#
# #### 1. Range of Definition
#
# Given _|S|_ > 0, i.e. the binary representation of the DNA string is not an empty string, then
#
# _0 < L < |S|_
#
# _L_ is bounded between zero and the length of _S_.
#
# #### 2. Upper Bound
# If _L == |S|_ then _S_ is random. [citation needed]
#
# If _L > S_ then _P_ is not a minimumum-length program which yields _S_. A program _Pmin_ of length _|S|_, which is a copy of _S_, is sufficient in all cases.
#
# #### 3. Lower Bound
# We will not consider progams of bit-length _< 0_.
#
# ### DNA Entropy
# Binary entropy of a particular encoding of a string of DNA sequence. Entropy is directly proportional to information in this context [why].
#
# ### DNA Compressability
# Compressability of a DNA string, or it's encoded binary representation. When encoded this will depend on the encoding bit size. Compressability is inverserly proportional to information in this context.

# %% [markdown]
# ## Hypothesis
# The information signals[define] in the DNA sequence of [SPECIES] correlate with some known functional or structural annotations of the DNA sequence.

# %% [markdown]
# ## Method
#
# ### 01 Sampling
# Sample some sequences from [SPECIES].
#
# [010_explore_data](010_explore_data.ipynb)
#
#
# ### 02 Encoding
# [020_encoding_sequences_as_binary](020_encoding_sequences_as_binary.ipynb)
#
# ### 03 Windowing
# Define windowing method(s).
#
# ### 04 Measure Information
# Generate information signals for data window sets.
#
#
# ### 04 Combine signals
# Combine corresponding data window sets.
#
# ### Compare
# Compare combined(and individual?) signals with annotation labels for position overlap.
